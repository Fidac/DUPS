# %%
from pathlib import Path
import json

network = open("./data/jsons/Network/networks.json", 'r', encoding='utf-8')
microservices = open("./data/jsons/Microservices/microservices.json", 'r', encoding='utf-8')
archDegrad = open("./data/jsons/ArchitecturalDegradation/response.json", 'r', encoding='utf-8')
codeSmell = open("./data/jsons/CodeSmellDetection/response.json", 'r', encoding='utf-8')
medicine = open("./data/jsons/Medicine/response.json", 'r', encoding='utf-8')

network_documents = json.load(network)
microservices_documents = json.load(microservices)
archDegrad_documents = json.load(archDegrad)
codeSmell_documents = json.load(codeSmell)
medicine_documents = json.load(medicine)

network.close()
microservices.close()
archDegrad.close()
codeSmell.close()
medicine.close()

documents = {}
#documents["network"] = network_documents
documents["microservices"] = microservices_documents
type(network_documents)


merge_documents = microservices_documents + archDegrad_documents + codeSmell_documents
merge_documents[101]

# %%
# !pip install sentencepiece

# %%
from transformers import BertTokenizer, BertModel, BertForMaskedLM, XLNetConfig, XLNetModel, XLNetTokenizer
import torch
from torch.nn.functional import one_hot

class BERTComponent:
    tokenizer = None
    bert_model = None

    def __init__(self, model):
        self.bert_vector_size = 3072
        self.sent_vector_size = 768
        self.model = model
        print("Tokenizer: ", BERTComponent.tokenizer)
        self.tokenizer = BERTComponent.tokenizer if BERTComponent.tokenizer else BertTokenizer.from_pretrained(model)
        BERTComponent.tokenizer = self.tokenizer
        self.bert_model = BERTComponent.bert_model if BERTComponent.bert_model else BertModel.from_pretrained(model)
        BERTComponent.bert_model = self.bert_model
        self.bert_model.eval()


    def get_bert_spans(self, words, bert_tokens):
        if self.model == 'bert-large-uncased':
            words = [self._flat_word(word) for word in words]

        i = 0
        j = 1
        idx = 0

        bert_words_indexes = []
        bert_words = []
        while i < len(words):
            word = words[i]

            bert_word = bert_tokens[j]
            bert_word = bert_word[2:] if bert_word.startswith("##") else bert_word
            bert_word = bert_word[idx:]

            #Spacing control
            if word in [" ", "  ", "   "]:
                bert_words.append([word])
                bert_words_indexes.append([-1])

            #When the current word is [UNK] for bert
            elif bert_word == "[UNK]":
                bert_words.append(["[UNK]"])
                bert_words_indexes.append([j])
                j += 1
                idx = 0

            #When the current word is contained in bert token. Very weird
            elif len(word) < len(bert_word) and bert_word.find(word) >= 0:
                bert_words.append([bert_word])
                bert_words_indexes.append([j])

                idx = bert_word.find(word) + len(word)
                if idx == len(bert_word):
                    j += 1
                    idx = 0

            #Otherwise
            else:
                k = 0
                span = []
                span_indexes = []

                while k < len(word):
                    if word.find(bert_word, k) == k:
                        span.append(bert_word)
                        span_indexes.append(j)
                        k += len(bert_word)
                        j += 1
                        idx = 0
                        bert_word = bert_tokens[j]
                        bert_word = bert_word[2:] if bert_word.startswith("##") else bert_word
                    else:
                        print("Error")
                        return bert_words, bert_words_indexes

                bert_words.append(span)
                bert_words_indexes.append(span_indexes)

            i += 1

        assert len(bert_words_indexes) == len(words)

        return bert_words, bert_words_indexes

    def _flat_word(self, word):
        word = word.lower()
        word = word.replace("ñ", "n")
        word = word.replace("á", "a")
        word = word.replace("é", "e")
        word = word.replace("í", "i")
        word = word.replace("ó", "o")
        word = word.replace("ú", "u")
        word = word.replace("ä", "a")
        word = word.replace("ü", "u")
        word = word.replace("ö", "o")
        word = word.replace("ū", "u")
        word = word.replace("ā", "a")
        word = word.replace("ī", "i")
        word = word.replace("ș", "s")
        word = word.replace("ã", "a")
        word = word.replace("ô", "o")

        return word

    def _sum_merge(self, vectors):
        return torch.sum(torch.stack(vectors), dim=0)

    def _mean_merge(self, vectors):
        return torch.mean(torch.stack(vectors), dim=0)

    def _last_merge(self, vectors):
        return vectors[-1]

    def _get_merge_tensors(self, token_vec_sums, words_indexes):
        pad_tensor = torch.zeros(self.bert_vector_size)
        real_vec = []
        for word_indexes in words_indexes:
            vectors = [(token_vec_sums[idx] if idx != -1 else pad_tensor) for idx in word_indexes]
            real_vec.append(self._mean_merge(vectors))

        return real_vec

    def get_bert_embeddings(self, sentence, spans):
        tokenized_sentence = self.tokenizer.tokenize(sentence)
        tokenized_sentence = ['[CLS]'] + tokenized_sentence + ['[SEP]']
        indexed_tokens = self.tokenizer.convert_tokens_to_ids(tokenized_sentence)
        segments_ids = [1] * len(tokenized_sentence)

        tokens_tensor = torch.tensor([indexed_tokens])
        segments_tensors = torch.tensor([segments_ids])

        with torch.no_grad():
            encoded_layers = self.bert_model(tokens_tensor, segments_tensors, output_hidden_states=True)

        #print("This is enconded layers: ", len(encoded_layers.hidden_states))
        
        token_embeddings = torch.stack(encoded_layers.hidden_states, dim=0)
        token_embeddings = torch.squeeze(token_embeddings, dim=1)
        token_embeddings = token_embeddings.permute(1,0,2)

        token_vec_sums = []
        for token in token_embeddings:
            cat_vec = torch.cat((token[-1], token[-2], token[-3], token[-4]), dim=-1)
            token_vec_sums.append(cat_vec)

        words = [sentence[beg:end] for (beg, end) in spans]
        bert_words, bert_words_indexes = self.get_bert_spans(words, tokenized_sentence)

        bert_embeddings = self._get_merge_tensors(token_vec_sums, bert_words_indexes)
        sentence_embedding = torch.mean(torch.stack(token_vec_sums), dim=0)
        
        return bert_embeddings, sentence_embedding

# %%
from nltk.tokenize import TreebankWordTokenizer as twt
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

class DocumentRanker:
    
    def __init__(self, documents):
        self.documents = documents
        self.bert = BERTComponent('bert-large-cased')
        self.__model = SentenceTransformer('bert-large-cased')
    
    def __get_info_rep(self, document):
        pass
    
    def __get_embedding(self, text):
#         spans = twt().span_tokenize(text)
#         text_word_embeddings, text_embedding = self.bert.get_bert_embeddings(text, spans)
#         return text_embedding
        return self.__model.encode(text)
    
    def get_related_documents(self, query, number_of_documents):
        index = {}
        last = 0
        related_documents = []
        
        q_sent_embedding = self.__get_embedding(query)
        
        for document in self.documents:
            abstract = document['documentTitle'] + " " + document['workAbstract'] + ". "
            for keyword in document['authorKeywords']:
                abstract += keyword['keyword']
            abstract_embedding = self.__get_embedding(abstract)
            #index[last] = torch.dot(q_sent_embedding, abstract_embedding)
            index[last] = cosine_similarity([q_sent_embedding], [abstract_embedding])[0][0]
            last += 1
        
        doc_scores = list(index.items())
        doc_scores = [(x[0], x[1].tolist()) for x in doc_scores]
        doc_scores= sorted(doc_scores, key = lambda x: x[1], reverse=True)
        #print("Scores: ", scores)
#         probs = F.softmax(scores, dim=0)
#         probs = [t.tolist() for t in probs]
#         probs.sort(reverse=True)
        #print("Probs: ", probs)
        print(doc_scores)
        
        if number_of_documents > len(doc_scores):
            return doc_scores
        else:
            return doc_scores[:number_of_documents]

# %%
docs = merge_documents
ranker = DocumentRanker(docs)
print(ranker.bert.tokenizer)

# %%
related_docs = ranker.get_related_documents("Code smell and anti-patterns degrades the architecture", 10)
related_docs

# %%
docs[396]

# %%
import re

def get_spans(sentence, begin):
    # printing original string
    print("The original string is : " + str(sentence))

    # regex to get words, loop to get each start and end index
    res = [(begin + ele.start(), begin + ele.end()) for ele in re.finditer(r'\S+', sentence)]

    # printing result
    print("Word Ranges are : " + str(res))

# %%
get_spans("Companies that produce energy drinks claim that they can increase alertness and improve physical and mental performance.", 14182)

# %%
get_spans("These services employ specially trained people and specially equipped centers.", 14303)

# %%
from scripts.utils import Collection
from pathlib import Path

train_20 = Collection()
train_20.load(Path("./data/training/scenario.txt"))

development_20 = Collection()
development_20.load(Path("./data/development/main/scenario.txt"))

scenario1_20A = Collection()
scenario1_20A.load(Path("./data/testing/scenario1-main/scenario.txt"), keyphrases=False, relations=False)
scenario1_20B = Collection()
scenario1_20B.load(Path("./data/testing/scenario1-main/scenario.txt"), keyphrases=True, relations=False)

# scenario2_20 = Collection()
# scenario2_20.load(Path("./data/testing/scenario2-taskA/scenario.txt"), keyphrases=False, relations=False)

# scenario3_20 = Collection()
# scenario3_20.load(Path("./data/testing/scenario3-taskB/scenario.txt"), relations=False)

# scenario4_20A = Collection()
# scenario4_20A.load(Path("./data/testing/scenario4-transfer/scenario.txt"), keyphrases=False, relations=False)
# scenario4_20B = Collection()
# scenario4_20B.load(Path("./data/testing/scenario4-transfer/scenario.txt"), keyphrases=False, relations=False)
# Out:
# This is the line  T1	Concept 3 10;11 22;23 32	chronic lymphocytic leukemia
#
# ['T1', 'Concept 3 10;11 22;23 32', 'chronic lymphocytic leukemia']
# This is the line  T2	Concept 52 64	lymphocytes
#
# ['T2', 'Concept 52 64', 'lymphocytes']
# This is the line  T3	Concept 75 80;81 86;87 93	white blood cell
#
# ['T3', 'Concept 75 80;81 86;87 93', 'white blood cell']
# This is the line  T4	Predicate 94 98	most
#
# ['T4', 'Predicate 94 98', 'most']
# This is the line  T5	Concept 99 110	arrhythmias
#
# ['T5', 'Concept 99 110', 'arrhythmias']
# This is the line  T6	Action 129 137	problems
#
# ['T6', 'Action 129 137', 'problems']
# This is the line  T7	Concept 145 151	heart
#
# ['T7', 'Concept 145 151', 'heart']
# This is the line  T8	Concept 153 163;164 171	electrical system
#
# ['T8', 'Concept 153 163;164 171', 'electrical system']
# This is the line  T9	Concept 176 180	TEPT
#
# ['T9', 'Concept 176 180', 'TEPT']
# This is the line  T10	Action 181 187	begins
#
# ['T10', 'Action 181 187', 'begins']
# This is the line  T11	Concept 191 200	different
#
# ['T11', 'Concept 191 200', 'different']
# This is the line  T12	Concept 201 206	times
#
# ['T12', 'Concept 201 206', 'times']
# This is the line  T13	Action 207 216	depending
#
# ['T13', 'Action 207 216', 'depending']
# This is the line  T14	Concept 224 231	person
#
# ['T14', 'Concept 224 231', 'person']
# This is the line  T15	Reference 232 236	This
#
# ['T15', 'Reference 232 236', 'This']
# This is the line  T16	Action 241 247	affect
#
# ['T16', 'Action 241 247', 'affect']
# This is the line  T17	Predicate 254 261	ability
#
# ['T17', 'Predicate 254 261', 'ability']
# This is the line  T18	Action 265 269	walk
#
# ['T18', 'Action 265 269', 'walk']
# This is the line  T19	Action 271 276	crawl
#
# ['T19', 'Action 271 276', 'crawl']
# This is the line  T20	Action 278 285	breathe
#
# ['T20', 'Action 278 285', 'breathe']
# This is the line  T21	Action 287 294	swallow
#
# ['T21', 'Action 287 294', 'swallow']
# This is the line  T22	Action 300 307	control
#
# ['T22', 'Action 300 307', 'control']
# This is the line  T23	Concept 314 318	head
#
# ['T23', 'Concept 314 318', 'head']
# This is the line  T24	Concept 323 328	neck
#
# ['T24', 'Concept 323 328', 'neck']
# This is the line  T25	Concept 329 334	Mumps
#
# ['T25', 'Concept 329 334', 'Mumps']
# This is the line  T26	Concept 352 357;358 364	mumps virus
#
# ['T26', 'Concept 352 357;358 364', 'mumps virus']
# This is the line  T27	Concept 365 372	cocaine
#
# ['T27', 'Concept 365 372', 'cocaine']
# This is the line  T28	Concept 378 383	white
#
# ['T28', 'Concept 378 383', 'white']
# This is the line  T29	Concept 384 391	powder
#
# ['T29', 'Concept 384 391', 'powder']
# This is the line  T30	Concept 392 403	Indigestion
#
# ['T30', 'Concept 392 403', 'Indigestion']
# This is the line  T31	Action 420 426	eating
#
# ['T31', 'Action 420 426', 'eating']
# This is the line  T32	Concept 427 430;431 435	too much
#
# ['T32', 'Concept 427 430;431 435', 'too much']
# This is the line  T33	Concept 439 442;443 447	too fast
#
# ['T33', 'Concept 439 442;443 447', 'too fast']
# This is the line  T34	Action 449 458	ingesting
#
# ['T34', 'Action 449 458', 'ingesting']
# This is the line  T35	Concept 459 464	fatty
#
# ['T35', 'Concept 459 464', 'fatty']
# This is the line  T36	Concept 465 470	foods
#
# ['T36', 'Concept 465 470', 'foods']
# This is the line  T37	Action 474 480	eating
#
# ['T37', 'Action 474 480', 'eating']
# This is the line  T38	Concept 493 500	stress
#
# ['T38', 'Concept 493 500', 'stress']
# This is the line  T39	Action 517 521	feel
#
# ['T39', 'Action 517 521', 'feel']
# This is the line  T40	Action 522 529	itching
#
# ['T40', 'Action 522 529', 'itching']
# This is the line  T41	Predicate 530 533	all
#
# ['T41', 'Predicate 530 533', 'all']
# This is the line  T42	Concept 544 549	body
#
# ['T42', 'Concept 544 549', 'body']
# This is the line  T43	Concept 555 560	hives
#
# ['T43', 'Concept 555 560', 'hives']
# This is the line  T44	Action 566 570	keep
#
# ['T44', 'Action 566 570', 'keep']
# This is the line  T45	Action 571 577;578 582	coming back
#
# ['T45', 'Action 571 577;578 582', 'coming back']
# This is the line  T46	Action 592 599	itching
#
# ['T46', 'Action 592 599', 'itching']
# This is the line  T47	Concept 617 622	cause
#
# ['T47', 'Concept 617 622', 'cause']
# This is the line  T48	Action 632 636	need
#
# ['T48', 'Action 632 636', 'need']
# This is the line  T49	Concept 637 644;645 655	medical attention
#
# ['T49', 'Concept 637 644;645 655', 'medical attention']
# This is the line  T50	Reference 656 658	It
#
# ['T50', 'Reference 656 658', 'It']
# This is the line  T51	Action 659 666	exposes
#
# ['T51', 'Action 659 666', 'exposes']
# This is the line  T52	Concept 674 681	harmful
#
# ['T52', 'Concept 674 681', 'harmful']
# This is the line  T53	Concept 682 686	rays
#
# ['T53', 'Concept 682 686', 'rays']
# This is the line  T54	Action 691 700	increases
#
# ['T54', 'Action 691 700', 'increases']
# This is the line  T55	Predicate 706 710	risk
#
# ['T55', 'Predicate 706 710', 'risk']
# This is the line  T56	Concept 714 720	health
#
# ['T56', 'Concept 714 720', 'health']
# This is the line  T57	Action 721 729	problems
#
# ['T57', 'Action 721 729', 'problems']
# This is the line  T58	Concept 738 746	melanoma
#
# ['T58', 'Concept 738 746', 'melanoma']
# This is the line  T59	Concept 757 761;762 770	skin cancers
#
# ['T59', 'Concept 757 761;762 770', 'skin cancers']
# This is the line  T60	Concept 771 782	angiography
#
# ['T60', 'Concept 771 782', 'angiography']
# This is the line  T61	Concept 786 795;796 798;799 802;803 808	angiogram of the heart
#
# ['T61', 'Concept 786 795;796 798;799 802;803 808', 'angiogram of the heart']
# This is the line  T62	Concept 814 823	procedure
#
# ['T62', 'Concept 814 823', 'procedure']
# This is the line  T63	Action 829 833	uses
#
# ['T63', 'Action 829 833', 'uses']
# This is the line  T64	Concept 834 842;843 847	contrast dyes
#
# ['T64', 'Concept 834 842;843 847', 'contrast dyes']
# This is the line  T65	Concept 852 858	x-rays
#
# ['T65', 'Concept 852 858', 'x-rays']
# This is the line  T66	Action 862 866	look
#
# ['T66', 'Action 862 866', 'look']
# This is the line  T67	Predicate 867 873	inside
#
# ['T67', 'Predicate 867 873', 'inside']
# This is the line  T68	Concept 878 887	arteries
#
# ['T68', 'Concept 878 887', 'arteries']
# This is the line  T69	Concept 906 910	drug
#
# ['T69', 'Concept 906 910', 'drug']
# This is the line  T70	Concept 921 927	victim
#
# ['T70', 'Concept 921 927', 'victim']
# This is the line  T71	Action 938 944	refuse
#
# ['T71', 'Action 938 944', 'refuse']
# This is the line  T72	Action 948 954	defend
#
# ['T72', 'Action 948 954', 'defend']
# This is the line  T73	Concept 971 977	sexual
#
# ['T73', 'Concept 971 977', 'sexual']
# This is the line  T74	Action 978 986	assault
#
# ['T74', 'Action 978 986', 'assault']
# This is the line  T75	Concept 991 997	retina
#
# ['T75', 'Concept 991 997', 'retina']
# This is the line  T76	Concept 1003 1008;1009 1011;1012 1018	layer of tissue
#
# ['T76', 'Concept 1003 1008;1009 1011;1012 1018', 'layer of tissue']
# This is the line  T77	Predicate 1022 1025;1026 1030	the back
#
# ['T77', 'Predicate 1022 1025;1026 1030', 'the back']
# This is the line  T78	Concept 1038 1041	eye
#
# ['T78', 'Concept 1038 1041', 'eye']
# This is the line  T79	Action 1047 1053	senses
#
# ['T79', 'Action 1047 1053', 'senses']
# This is the line  T80	Concept 1054 1059	light
#
# ['T80', 'Concept 1054 1059', 'light']
# This is the line  T81	Action 1064 1069	sends
#
# ['T81', 'Action 1064 1069', 'sends']
# This is the line  T82	Concept 1070 1076	images
#
# ['T82', 'Concept 1070 1076', 'images']
# This is the line  T83	Concept 1084 1090	brain
#
# ['T83', 'Concept 1084 1090', 'brain']
# This is the line  T84	Concept 1091 1101;1102 1106	palliative care
#
# ['T84', 'Concept 1091 1101;1102 1106', 'palliative care']
# This is the line  T85	Action 1110 1119	treatment
#
# ['T85', 'Action 1110 1119', 'treatment']
# This is the line  T86	Concept 1128 1138	discomfort
#
# ['T86', 'Concept 1128 1138', 'discomfort']
# This is the line  T87	Concept 1140 1148	symptoms
#
# ['T87', 'Concept 1140 1148', 'symptoms']
# This is the line  T88	Concept 1153 1159	stress
#
# ['T88', 'Concept 1153 1159', 'stress']
# This is the line  T89	Action 1160 1166	caused
#
# ['T89', 'Action 1160 1166', 'caused']
# This is the line  T90	Concept 1170 1177	serious
#
# ['T90', 'Concept 1170 1177', 'serious']
# This is the line  T91	Concept 1178 1186	illness
#
# ['T91', 'Concept 1178 1186', 'illness']
# This is the line  T92	Concept 1189 1198	violation
#
# ['T92', 'Concept 1189 1198', 'violation']
# This is the line  T93	Concept 1206 1212;1213 1221	sexual activity
#
# ['T93', 'Concept 1206 1212;1213 1221', 'sexual activity']
# This is the line  T94	Concept 1231 1234	you
#
# ['T94', 'Concept 1231 1234', 'you']
# This is the line  T95	Action 1235 1239;1240 1243;1244 1249	have not given
#
# ['T95', 'Action 1235 1239;1240 1243;1244 1249', 'have not given']
# This is the line  T96	Concept 1255 1263	consent
#
# ['T96', 'Concept 1255 1263', 'consent']
# This is the line  T97	Concept 1264 1271;1272 1273	vitamin D
#
# ['T97', 'Concept 1264 1271;1272 1273', 'vitamin D']
# This is the line  T98	Action 1279 1284	plays
#
# ['T98', 'Action 1279 1284', 'plays']
# This is the line  T99	Concept 1287 1291	role
#
# ['T99', 'Concept 1287 1291', 'role']
# This is the line  T100	Concept 1300 1307;1329 1336	nervous system
#
# ['T100', 'Concept 1300 1307;1329 1336', 'nervous system']
# This is the line  T101	Concept 1309 1317;1329 1336	muscular system
#
# ['T101', 'Concept 1309 1317;1329 1336', 'muscular system']
# This is the line  T102	Concept 1322 1328;1329 1336	immune system
#
# ['T102', 'Concept 1322 1328;1329 1336', 'immune system']
# This is the line  T103	Concept 1338 1346;1347 1352	varicose veins
#
# ['T103', 'Concept 1338 1346;1347 1352', 'varicose veins']
# This is the line  T104	Concept 1362 1369	common
#
# ['T104', 'Concept 1362 1369', 'common']
# This is the line  T105	Reference 1370 1374	This
#
# ['T105', 'Reference 1370 1374', 'This']
# This is the line  T106	Concept 1384 1394	alcoholism
#
# ['T106', 'Concept 1384 1394', 'alcoholism']
# This is the line  T107	Concept 1399 1406	alcohol
#
# ['T107', 'Concept 1399 1406', 'alcohol']
# This is the line  T108	Action 1407 1413	abuse
#
# ['T108', 'Action 1407 1413', 'abuse']
# This is the line  T109	Concept 1416 1423	surgeon
#
# ['T109', 'Concept 1416 1423', 'surgeon']
# This is the line  T110	Action 1428 1439	reconstruct
#
# ['T110', 'Action 1428 1439', 'reconstruct']
# This is the line  T111	Concept 1442 1448	breast
#
# ['T111', 'Concept 1442 1448', 'breast']
# This is the line  T112	Predicate 1452 1461	different
#
# ['T112', 'Predicate 1452 1461', 'different']
# This is the line  T113	Concept 1462 1467	ways
#
# ['T113', 'Concept 1462 1467', 'ways']
# This is the line  T114	Concept 1470 1476	person
#
# ['T114', 'Concept 1470 1476', 'person']
# This is the line  T115	Concept 1484 1488	dual
#
# ['T115', 'Concept 1484 1488', 'dual']
# This is the line  T116	Concept 1489 1498	diagnosis
#
# ['T116', 'Concept 1489 1498', 'diagnosis']
# This is the line  T117	Action 1499 1502	has
#
# ['T117', 'Action 1499 1502', 'has']
# This is the line  T118	Concept 1505 1511	mental
#
# ['T118', 'Concept 1505 1511', 'mental']
# This is the line  T119	Concept 1516 1523	alcohol
#
# ['T119', 'Concept 1516 1523', 'alcohol']
# This is the line  T120	Concept 1527 1531	drug
#
# ['T120', 'Concept 1527 1531', 'drug']
# This is the line  T121	Action 1532 1539	problem
#
# ['T121', 'Action 1532 1539', 'problem']
# This is the line  T122	Predicate 1547 1551	same
#
# ['T122', 'Predicate 1547 1551', 'same']
# This is the line  T123	Concept 1552 1557	time
#
# ['T123', 'Concept 1552 1557', 'time']
# This is the line  T124	Concept 1558 1569	indigestion
#
# ['T124', 'Concept 1558 1569', 'indigestion']
# This is the line  T125	Action 1579 1583	sign
#
# ['T125', 'Action 1579 1583', 'sign']
# This is the line  T126	Predicate 1589 1593	more
#
# ['T126', 'Predicate 1589 1593', 'more']
# This is the line  T127	Concept 1594 1601	serious
#
# ['T127', 'Concept 1594 1601', 'serious']
# This is the line  T128	Concept 1602 1610	problem
#
# ['T128', 'Concept 1602 1610', 'problem']
# This is the line  T129	Concept 1614 1625	adolescence
#
# ['T129', 'Concept 1614 1625', 'adolescence']
# This is the line  T130	Action 1646 1654	changes
#
# ['T130', 'Action 1646 1654', 'changes']
# This is the line  T131	Concept 1655 1661	animal
#
# ['T131', 'Concept 1655 1661', 'animal']
# This is the line  T132	Action 1662 1667	bites
#
# ['T132', 'Action 1662 1667', 'bites']
# This is the line  T133	Action 1679 1682	put
#
# ['T133', 'Action 1679 1682', 'put']
# This is the line  T134	Concept 1686 1692	danger
#
# ['T134', 'Concept 1686 1692', 'danger']
# This is the line  T135	Concept 1697 1701	life
#
# ['T135', 'Concept 1697 1701', 'life']
# This is the line  T136	Concept 1707 1714	serious
#
# ['T136', 'Concept 1707 1714', 'serious']
# This is the line  T137	Concept 1715 1722	medical
#
# ['T137', 'Concept 1715 1722', 'medical']
# This is the line  T138	Concept 1723 1731	problems
#
# ['T138', 'Concept 1723 1731', 'problems']
# This is the line  T139	Action 1745 1754	infected
#
# ['T139', 'Action 1745 1754', 'infected']
# This is the line  T140	Concept 1759 1768	testicles
#
# ['T140', 'Concept 1759 1768', 'testicles']
# This is the line  T141	Action 1780 1788	inflamed
#
# ['T141', 'Action 1780 1788', 'inflamed']
# This is the line  T142	Action 1792 1801	infected
#
# ['T142', 'Action 1792 1801', 'infected']
# This is the line  T143	Concept 1802 1810	hormones
#
# ['T143', 'Concept 1802 1810', 'hormones']
# This is the line  T144	Concept 1819 1823	body
#
# ['T144', 'Concept 1819 1823', 'body']
# This is the line  T145	Concept 1826 1834	chemical
#
# ['T145', 'Concept 1826 1834', 'chemical']
# This is the line  T146	Concept 1835 1846	messengers
#
# ['T146', 'Concept 1835 1846', 'messengers']
# This is the line  T147	Concept 1847 1852	smell
#
# ['T147', 'Concept 1847 1852', 'smell']
# This is the line  T148	Action 1853 1859	allows
#
# ['T148', 'Action 1853 1859', 'allows']
# This is the line  T149	Action 1866 1871	enjoy
#
# ['T149', 'Action 1866 1871', 'enjoy']
# This is the line  T150	Concept 1872 1878	scents
#
# ['T150', 'Concept 1872 1878', 'scents']
# This is the line  T151	Concept 1883 1894	fragrances
#
# ['T151', 'Concept 1883 1894', 'fragrances']
# This is the line  T152	Concept 1903 1908	roses
#
# ['T152', 'Concept 1903 1908', 'roses']
# This is the line  T153	Concept 1912 1919	coffee
#
# ['T153', 'Concept 1912 1919', 'coffee']
# This is the line  T154	Concept 1924 1933	treatment
#
# ['T154', 'Concept 1924 1933', 'treatment']
# This is the line  T155	Concept 1943 1950	surgery
#
# ['T155', 'Concept 1943 1950', 'surgery']
# This is the line  T156	Concept 1952 1964	radiotherapy
#
# ['T156', 'Concept 1952 1964', 'radiotherapy']
# This is the line  T157	Concept 1969 1982	chemotherapy
#
# ['T157', 'Concept 1969 1982', 'chemotherapy']
# This is the line  T158	Concept 1983 1990	Thyroid
#
# ['T158', 'Concept 1983 1990', 'Thyroid']
# This is the line  T159	Action 1991 1996	tests
#
# ['T159', 'Action 1991 1996', 'tests']
# This is the line  T160	Concept 2005 2010	blood
#
# ['T160', 'Concept 2005 2010', 'blood']
# This is the line  T161	Action 2011 2019	analysis
#
# ['T161', 'Action 2011 2019', 'analysis']
# This is the line  T162	Concept 2024 2031	imaging
#
# ['T162', 'Concept 2024 2031', 'imaging']
# This is the line  T163	Action 2032 2038	tests
#
# ['T163', 'Action 2032 2038', 'tests']
# This is the line  T164	Reference 2039 2045	Others
#
# ['T164', 'Reference 2039 2045', 'Others']
# This is the line  T165	Action 2046 2050	slow
#
# ['T165', 'Action 2046 2050', 'slow']
# This is the line  T166	Action 2055 2060	beats
#
# ['T166', 'Action 2055 2060', 'beats']
# This is the line  T167	Concept 2068 2073	heart
#
# ['T167', 'Concept 2068 2073', 'heart']
# This is the line  T168	Action 2077 2083	loosen
#
# ['T168', 'Action 2077 2083', 'loosen']
# This is the line  T169	Action 2088 2093	widen
#
# ['T169', 'Action 2088 2093', 'widen']
# This is the line  T170	Concept 2098 2103;2104 2112	blood vessels
#
# ['T170', 'Concept 2098 2103;2104 2112', 'blood vessels']
# This is the line  T171	Concept 2113 2123	Successful
#
# ['T171', 'Concept 2113 2123', 'Successful']
# This is the line  T172	Concept 2124 2131	results
#
# ['T172', 'Concept 2124 2131', 'results']
# This is the line  T173	Action 2135 2140	trips
#
# ['T173', 'Action 2135 2140', 'trips']
# This is the line  T174	Concept 2148 2156	bathroom
#
# ['T174', 'Concept 2148 2156', 'bathroom']
# This is the line  T175	Action 2157 2163;2164 2166	should be
#
# ['T175', 'Action 2157 2163;2164 2166', 'should be']
# This is the line  T176	Action 2167 2176	rewarded
#
# ['T176', 'Action 2167 2176', 'rewarded']
# This is the line  T177	Concept 2177 2188	Antibiotics
#
# ['T177', 'Concept 2177 2188', 'Antibiotics']
# This is the line  T178	Action 2189 2191;2192 2195;2196 2200	do not work
#
# ['T178', 'Action 2189 2191;2192 2195;2196 2200', 'do not work']
# This is the line  T179	Concept 2205 2210;2211 2222	viral infections
#
# ['T179', 'Concept 2205 2210;2211 2222', 'viral infections']
# This is the line  T180	Reference 2226 2229	you
#
# ['T180', 'Reference 2226 2229', 'you']
# This is the line  T181	Action 2240 2249	consuming
#
# ['T181', 'Action 2240 2249', 'consuming']
# This is the line  T182	Concept 2250 2258	caffeine
#
# ['T182', 'Concept 2250 2258', 'caffeine']
# This is the line  T183	Concept 2264 2271	regular
#
# ['T183', 'Concept 2264 2271', 'regular']
# This is the line  T184	Concept 2287 2295	suddenly
#
# ['T184', 'Concept 2287 2295', 'suddenly']
# This is the line  T185	Action 2296 2301	stop
#
# ['T185', 'Action 2296 2301', 'stop']
# This is the line  T186	Concept 2315 2323;2324 2335	caffeine withdrawal
#
# ['T186', 'Concept 2315 2323;2324 2335', 'caffeine withdrawal']
# This is the line  T187	Predicate 2342 2345;2346 2348;2349 2353	one in four
#
# ['T187', 'Predicate 2342 2345;2346 2348;2349 2353', 'one in four']
# This is the line  T188	Concept 2354 2360	people
#
# ['T188', 'Concept 2354 2360', 'people']
# This is the line  T189	Concept 2366 2369	HIV
#
# ['T189', 'Concept 2366 2369', 'HIV']
# This is the line  T190	Concept 2377 2383;2384 2390	United States
#
# ['T190', 'Concept 2377 2383;2384 2390', 'United States']
# This is the line  T191	Concept 2396 2402	woman
#
# ['T191', 'Concept 2396 2402', 'woman']
# This is the line  T192	Concept 2403 2413	Treatments
#
# ['T192', 'Concept 2403 2413', 'Treatments']
# This is the line  T193	Concept 2422 2432	medication
#
# ['T193', 'Concept 2422 2432', 'medication']
# This is the line  T194	Concept 2434 2447	psychotherapy
#
# ['T194', 'Concept 2434 2447', 'psychotherapy']
# This is the line  T195	Action 2453 2464	combination
#
# ['T195', 'Action 2453 2464', 'combination']
# This is the line  T196	Concept 2481 2486;2487 2493	nasal cavity
#
# ['T196', 'Concept 2481 2486;2487 2493', 'nasal cavity']
# This is the line  T197	Concept 2501 2507	tunnel
#
# ['T197', 'Concept 2501 2507', 'tunnel']
# This is the line  T198	Predicate 2513 2519	behind
#
# ['T198', 'Predicate 2513 2519', 'behind']
# This is the line  T199	Concept 2525 2529	nose
#
# ['T199', 'Concept 2525 2529', 'nose']
# This is the line  T200	Concept 2544 2547	air
#
# ['T200', 'Concept 2544 2547', 'air']
# This is the line  T201	Action 2548 2554	passes
#
# ['T201', 'Action 2548 2554', 'passes']
# This is the line  T202	Concept 2576 2582	throat
#
# ['T202', 'Concept 2576 2582', 'throat']
# This is the line  T203	Action 2592 2600	breathe
#
# ['T203', 'Action 2592 2600', 'breathe']
# This is the line  T204	Predicate 2601 2608	Several
#
# ['T204', 'Predicate 2601 2608', 'Several']
# This is the line  T205	Concept 2609 2617	problems
#
# ['T205', 'Concept 2609 2617', 'problems']
# This is the line  T206	Action 2622 2628	affect
#
# ['T206', 'Action 2622 2628', 'affect']
# This is the line  T207	Concept 2633 2640;2641 2648	adrenal glands
#
# ['T207', 'Concept 2633 2640;2641 2648', 'adrenal glands']
# This is the line  T208	Concept 2659 2666	tumors
#
# ['T208', 'Concept 2659 2666', 'tumors']
# This is the line  T209	Concept 2667 2674	Parents
#
# ['T209', 'Concept 2667 2674', 'Parents']
# This is the line  T210	Concept 2679 2687	children
#
# ['T210', 'Concept 2679 2687', 'children']
# This is the line  T211	Action 2688 2694	should
#
# ['T211', 'Action 2688 2694', 'should']
# This is the line  T212	Action 2698 2703	aware
#
# ['T212', 'Action 2698 2703', 'aware']
# This is the line  T213	Reference 2707 2712	these
#
# ['T213', 'Reference 2707 2712', 'these']
# This is the line  T214	Concept 2713 2721	dangers
#
# ['T214', 'Concept 2713 2721', 'dangers']
# This is the line  T215	Concept 2729 2735	people
#
# ['T215', 'Concept 2729 2735', 'people']
# This is the line  T216	Reference 2741 2745	this
#
# ['T216', 'Reference 2741 2745', 'this']
# This is the line  T217	Concept 2746 2754	syndrome
#
# ['T217', 'Concept 2746 2754', 'syndrome']
# This is the line  T218	Concept 2766 2773	cancers
#
# ['T218', 'Concept 2766 2773', 'cancers']
# This is the line  T219	Concept 2784 2791	hormone
#
# ['T219', 'Concept 2784 2791', 'hormone']
# This is the line  T220	Predicate 2800 2809	problems
#
# ['T220', 'Predicate 2800 2809', 'problems']
# This is the line  T221	Concept 2810 2819	Treatment
#
# ['T221', 'Concept 2810 2819', 'Treatment']
# This is the line  T222	Concept 2831 2837	fluids
#
# ['T222', 'Concept 2831 2837', 'fluids']
# This is the line  T223	Concept 2839 2850	intravenous
#
# ['T223', 'Concept 2839 2850', 'intravenous']
# This is the line  T224	Concept 2851 2861	analgesics
#
# ['T224', 'Concept 2851 2861', 'analgesics']
# This is the line  T225	Concept 2866 2876	artificial
#
# ['T225', 'Concept 2866 2876', 'artificial']
# This is the line  T226	Concept 2877 2886	nutrition
#
# ['T226', 'Concept 2877 2886', 'nutrition']
# This is the line  T227	Concept 2897 2901	days
#
# ['T227', 'Concept 2897 2901', 'days']
# This is the line  T228	Concept 2909 2918	hospital
#
# ['T228', 'Concept 2909 2918', 'hospital']
# This is the line  T229	Concept 2919 2925;2926 2935	Mental disorders
#
# ['T229', 'Concept 2919 2925;2926 2935', 'Mental disorders']
# This is the line  T230	Concept 2940 2946	common
#
# ['T230', 'Concept 2940 2946', 'common']
# This is the line  T231	Action 2952 2962	treatments
#
# ['T231', 'Action 2952 2962', 'treatments']
# This is the line  T232	Concept 2967 2977	available
#
# ['T232', 'Concept 2967 2977', 'available']
# This is the line  T233	Concept 2978 2988	Mammograms
#
# ['T233', 'Concept 2978 2988', 'Mammograms']
# This is the line  T234	Action 2989 2992	use
#
# ['T234', 'Action 2989 2992', 'use']
# This is the line  T235	Concept 2993 2999	X-rays
#
# ['T235', 'Concept 2993 2999', 'X-rays']
# This is the line  T236	Action 3003 3009	detect
#
# ['T236', 'Action 3003 3009', 'detect']
# This is the line  T237	Concept 3010 3016;3017 3024	breast cancer
#
# ['T237', 'Concept 3010 3016;3017 3024', 'breast cancer']
# This is the line  T238	Concept 3025 3033;3034 3040	Clinical trials
#
# ['T238', 'Concept 3025 3033;3034 3040', 'Clinical trials']
# This is the line  T239	Concept 3045 3053;3054 3061	research studies
#
# ['T239', 'Concept 3045 3053;3054 3061', 'research studies']
# This is the line  T240	Action 3067 3071	test
#
# ['T240', 'Action 3067 3071', 'test']
# This is the line  T241	Concept 3076 3080	well
#
# ['T241', 'Concept 3076 3080', 'well']
# This is the line  T242	Concept 3081 3088;3089 3100	medical discoveries
#
# ['T242', 'Concept 3081 3088;3089 3100', 'medical discoveries']
# This is the line  T243	Action 3108 3115	applied
#
# ['T243', 'Action 3108 3115', 'applied']
# This is the line  T244	Concept 3119 3128	patients
#
# ['T244', 'Concept 3119 3128', 'patients']
# This is the line  T245	Predicate 3129 3133	Some
#
# ['T245', 'Predicate 3129 3133', 'Some']
# This is the line  T246	Concept 3134 3140	people
#
# ['T246', 'Concept 3134 3140', 'people']
# This is the line  T247	Action 3141 3147	suffer
#
# ['T247', 'Action 3141 3147', 'suffer']
# This is the line  T248	Concept 3155 3162	disease
#
# ['T248', 'Concept 3155 3162', 'disease']
# This is the line  T249	Concept 3170 3186	hemochromatosis
#
# ['T249', 'Concept 3170 3186', 'hemochromatosis']
# This is the line  T250	Concept 3187 3197	Pesticides
#
# ['T250', 'Concept 3187 3197', 'Pesticides']
# This is the line  T251	Action 3211 3214	rid
#
# ['T251', 'Action 3211 3214', 'rid']
# This is the line  T252	Reference 3218 3223	them
#
# ['T252', 'Reference 3218 3223', 'them']
# This is the line  T253	Action 3227 3235	diagnose
#
# ['T253', 'Action 3227 3235', 'diagnose']
# This is the line  T254	Concept 3236 3246;3247 3256	infectious arthritis
#
# ['T254', 'Concept 3236 3246;3247 3256', 'infectious arthritis']
# This is the line  T255	Concept 3263 3269	doctor
#
# ['T255', 'Concept 3263 3269', 'doctor']
# This is the line  T256	Action 3270 3273	may
#
# ['T256', 'Action 3270 3273', 'may']
# This is the line  T257	Concept 3274 3278	test
#
# ['T257', 'Concept 3274 3278', 'test']
# This is the line  T258	Concept 3284 3289	blood
#
# ['T258', 'Concept 3284 3289', 'blood']
# This is the line  T259	Concept 3291 3296	urine
#
# ['T259', 'Concept 3291 3296', 'urine']
# This is the line  T260	Concept 3301 3306	joint
#
# ['T260', 'Concept 3301 3306', 'joint']
# This is the line  T261	Concept 3307 3313	fluid
#
# ['T261', 'Concept 3307 3313', 'fluid']
# This is the line  T262	Reference 3314 3317	You
#
# ['T262', 'Reference 3314 3317', 'You']
# This is the line  T263	Action 3325 3329	talk
#
# ['T263', 'Action 3325 3329', 'talk']
# This is the line  T264	Concept 3338 3344	doctor
#
# ['T264', 'Concept 3338 3344', 'doctor']
# This is the line  T265	Predicate 3345 3351	before
#
# ['T265', 'Predicate 3345 3351', 'before']
# This is the line  T266	Action 3352 3358	trying
#
# ['T266', 'Action 3352 3358', 'trying']
# This is the line  T267	Concept 3363 3374	alternative
#
# ['T267', 'Concept 3363 3374', 'alternative']
# This is the line  T268	Action 3375 3386	treatments
#
# ['T268', 'Action 3375 3386', 'treatments']
# This is the line  T269	Concept 3387 3396	Sinusitis
#
# ['T269', 'Concept 3387 3396', 'Sinusitis']
# This is the line  T270	Action 3403 3415	inflammation
#
# ['T270', 'Action 3403 3415', 'inflammation']
# This is the line  T271	Concept 3423 3431	sinuses
#
# ['T271', 'Concept 3423 3431', 'sinuses']
# This is the line  T272	Concept 3435 3442	general
#
# ['T272', 'Concept 3435 3442', 'general']
# This is the line  T273	Concept 3444 3451	phobias
#
# ['T273', 'Concept 3444 3451', 'phobias']
# This is the line  T274	Action 3452 3457	begin
#
# ['T274', 'Action 3452 3457', 'begin']
# This is the line  T275	Concept 3461 3470	childhood
#
# ['T275', 'Concept 3461 3470', 'childhood']
# This is the line  T276	Concept 3474 3485	adolescence
#
# ['T276', 'Concept 3474 3485', 'adolescence']
# This is the line  T277	Action 3490 3498	continue
#
# ['T277', 'Action 3490 3498', 'continue']
# This is the line  T278	Concept 3504 3514	adulthood
#
# ['T278', 'Concept 3504 3514', 'adulthood']
# This is the line  T279	Reference 3519 3524	those
#
# ['T279', 'Reference 3519 3524', 'those']
# This is the line  T280	Concept 3525 3531	people
#
# ['T280', 'Concept 3525 3531', 'people']
# This is the line  T281	Predicate 3537 3541	most
#
# ['T281', 'Predicate 3537 3541', 'most']
# This is the line  T282	Concept 3542 3548	common
#
# ['T282', 'Concept 3542 3548', 'common']
# This is the line  T283	Action 3549 3554	cause
#
# ['T283', 'Action 3549 3554', 'cause']
# This is the line  T284	Action 3558 3563	death
#
# ['T284', 'Action 3558 3563', 'death']
# This is the line  T285	Concept 3570 3579	infection
#
# ['T285', 'Concept 3570 3579', 'infection']
# This is the line  T286	Concept 3589 3599	pneumonia
#
# ['T286', 'Concept 3589 3599', 'pneumonia']
# This is the line  T287	Action 3605 3608;3609 3615	are formed
#
# ['T287', 'Action 3605 3608;3609 3615', 'are formed']
# This is the line  T288	Predicate 3619 3625	layers
#
# ['T288', 'Predicate 3619 3625', 'layers']
# This is the line  T289	Concept 3631 3639	hardened
#
# ['T289', 'Concept 3631 3639', 'hardened']
# This is the line  T290	Concept 3640 3647	protein
#
# ['T290', 'Concept 3640 3647', 'protein']
# This is the line  T291	Concept 3655 3662	keratin
#
# ['T291', 'Concept 3655 3662', 'keratin']
# This is the line  T292	Action 3678 3683	found
#
# ['T292', 'Action 3678 3683', 'found']
# This is the line  T293	Concept 3687 3691	hair
#
# ['T293', 'Concept 3687 3691', 'hair']
# This is the line  T294	Concept 3696 3701	skin
#
# ['T294', 'Concept 3696 3701', 'skin']
# This is the line  T295	Action 3702 3710	Tingling
#
# ['T295', 'Action 3702 3710', 'Tingling']
# This is the line  T296	Action 3714 3722	numbness
#
# ['T296', 'Action 3714 3722', 'numbness']
# This is the line  T297	Concept 3736 3745	diabetes
#
# ['T297', 'Concept 3736 3745', 'diabetes']
# This is the line  T298	Reference 3746 3749	Its
#
# ['T298', 'Reference 3746 3749', 'Its']
# This is the line  T299	Concept 3750 3754	main
#
# ['T299', 'Concept 3750 3754', 'main']
# This is the line  T300	Predicate 3755 3763	function
#
# ['T300', 'Predicate 3755 3763', 'function']
# This is the line  T301	Action 3770 3776	filter
#
# ['T301', 'Action 3770 3776', 'filter']
# This is the line  T302	Concept 3782 3788	blood
#
# ['T302', 'Concept 3782 3788', 'blood']
# This is the line  T303	Reference 3789 3793	This
#
# ['T303', 'Reference 3789 3793', 'This']
# This is the line  T304	Concept 3806 3813	serious
#
# ['T304', 'Concept 3806 3813', 'serious']
# This is the line  T305	Concept 3823 3828	fatal
#
# ['T305', 'Concept 3823 3828', 'fatal']
# This is the line  T306	Concept 3829 3835	health
#
# ['T306', 'Concept 3829 3835', 'health']
# This is the line  T307	Action 3836 3845	problems
#
# ['T307', 'Action 3836 3845', 'problems']
# This is the line  T308	Reference 3849 3852	you
#
# ['T308', 'Reference 3849 3852', 'you']
# This is the line  T309	Action 3853 3857	have
#
# ['T309', 'Action 3853 3857', 'have']
# This is the line  T310	Concept 3858 3869	prediabetes
#
# ['T310', 'Concept 3858 3869', 'prediabetes']
# This is the line  T311	Concept 3890 3895	blood
#
# ['T311', 'Concept 3890 3895', 'blood']
# This is the line  T312	Concept 3896 3903	glucose
#
# ['T312', 'Concept 3896 3903', 'glucose']
# This is the line  T313	Concept 3915 3920	sugar
#
# ['T313', 'Concept 3915 3920', 'sugar']
# This is the line  T314	Predicate 3922 3928	levels
#
# ['T314', 'Predicate 3922 3928', 'levels']
# This is the line  T315	Predicate 3933 3937	more
#
# ['T315', 'Predicate 3933 3937', 'more']
# This is the line  T316	Concept 3938 3942	high
#
# ['T316', 'Concept 3938 3942', 'high']
# This is the line  T317	Concept 3948 3954	normal
#
# ['T317', 'Concept 3948 3954', 'normal']
# This is the line  T318	Concept 3963 3967	high
#
# ['T318', 'Concept 3963 3967', 'high']
# This is the line  T319	Predicate 3968 3974	enough
#
# ['T319', 'Predicate 3968 3974', 'enough']
# This is the line  T320	Action 3981 3990	diagnosed
#
# ['T320', 'Action 3981 3990', 'diagnosed']
# This is the line  T321	Concept 3996 4005	diabetes
#
# ['T321', 'Concept 3996 4005', 'diabetes']
# This is the line  T322	Concept 4006 4009;4010 4016	Low weight
#
# ['T322', 'Concept 4006 4009;4010 4016', 'Low weight']
# This is the line  T323	Concept 4010 4016	weight
#
# ['T323', 'Concept 4010 4016', 'weight']
# This is the line  T324	Predicate 4023 4027	more
#
# ['T324', 'Predicate 4023 4027', 'more']
# This is the line  T325	Concept 4028 4031	low
#
# ['T325', 'Concept 4028 4031', 'low']
# This is the line  T326	Concept 4040 4047	healthy
#
# ['T326', 'Concept 4040 4047', 'healthy']
# This is the line  T327	Action 4064 4068	have
#
# ['T327', 'Action 4064 4068', 'have']
# This is the line  T328	Concept 4069 4077	diabetes
#
# ['T328', 'Concept 4069 4077', 'diabetes']
# This is the line  T329	Concept 4100 4104	eyes
#
# ['T329', 'Concept 4100 4104', 'eyes']
# This is the line  T330	Action 4105 4113	examined
#
# ['T330', 'Action 4105 4113', 'examined']
# This is the line  T331	Predicate 4114 4118	once
#
# ['T331', 'Predicate 4114 4118', 'once']
# This is the line  T332	Concept 4121 4126	year
#
# ['T332', 'Concept 4121 4126', 'year']
# This is the line  T333	Action 4127 4133	Eating
#
# ['T333', 'Action 4127 4133', 'Eating']
# This is the line  T334	Concept 4134 4146	nutritiously
#
# ['T334', 'Concept 4134 4146', 'nutritiously']
# This is the line  T335	Concept 4154 4164	difficult
#
# ['T335', 'Concept 4154 4164', 'difficult']
# This is the line  T336	Concept 4172 4178;4179 4185	United States
#
# ['T336', 'Concept 4172 4178;4179 4185', 'United States']
# This is the line  T337	Predicate 4187 4195	millions
#
# ['T337', 'Predicate 4187 4195', 'millions']
# This is the line  T338	Concept 4199 4205	people
#
# ['T338', 'Concept 4199 4205', 'people']
# This is the line  T339	Action 4206 4212	suffer
#
# ['T339', 'Action 4206 4212', 'suffer']
# This is the line  T340	Concept 4213 4220	injures
#
# ['T340', 'Concept 4213 4220', 'injures']
# This is the line  T341	Predicate 4221 4226	every
#
# ['T341', 'Predicate 4221 4226', 'every']
# This is the line  T342	Concept 4227 4232	year
#
# ['T342', 'Concept 4227 4232', 'year']
# This is the line  T343	Concept 4233 4237	High
#
# ['T343', 'Concept 4233 4237', 'High']
# This is the line  T344	Concept 4238 4243;4244 4252	blood pressure
#
# ['T344', 'Concept 4238 4243;4244 4252', 'blood pressure']
# This is the line  T345	Concept 4266 4278	hypertension
#
# ['T345', 'Concept 4266 4278', 'hypertension']
# This is the line  T346	Action 4288 4291	has
#
# ['T346', 'Action 4288 4291', 'has']
# This is the line  T347	Concept 4295 4304	symptoms
#
# ['T347', 'Concept 4295 4304', 'symptoms']
# This is the line  T348	Concept 4305 4308	Gas
#
# ['T348', 'Concept 4305 4308', 'Gas']
# This is the line  T349	Concept 4313 4316	ash
#
# ['T349', 'Concept 4313 4316', 'ash']
# This is the line  T350	Concept 4326 4333	volcano
#
# ['T350', 'Concept 4326 4333', 'volcano']
# This is the line  T351	Action 4338 4344	injure
#
# ['T351', 'Action 4338 4344', 'injure']
# This is the line  T352	Concept 4349 4354	lungs
#
# ['T352', 'Concept 4349 4354', 'lungs']
# This is the line  T353	Concept 4358 4363	young
#
# ['T353', 'Concept 4358 4363', 'young']
# This is the line  T354	Concept 4364 4372	children
#
# ['T354', 'Concept 4364 4372', 'children']
# This is the line  T355	Concept 4378 4385	elderly
#
# ['T355', 'Concept 4378 4385', 'elderly']
# This is the line  T356	Concept 4390 4396	people
#
# ['T356', 'Concept 4390 4396', 'people']
# This is the line  T357	Concept 4402 4408	severe
#
# ['T357', 'Concept 4402 4408', 'severe']
# This is the line  T358	Concept 4409 4420;4421 4430	respiratory diseases
#
# ['T358', 'Concept 4409 4420;4421 4430', 'respiratory diseases']
# This is the line  T359	Concept 4438 4443	germs
#
# ['T359', 'Concept 4438 4443', 'germs']
# This is the line  T360	Action 4444 4450	remain
#
# ['T360', 'Action 4444 4450', 'remain']
# This is the line  T361	Concept 4458 4462	nose
#
# ['T361', 'Concept 4458 4462', 'nose']
# This is the line  T362	Concept 4467 4473	throat
#
# ['T362', 'Concept 4467 4473', 'throat']
# This is the line  T363	Concept 4481 4487	child
#
# ['T363', 'Concept 4481 4487', 'child']
# This is the line  T364	Action 4520 4525	sick
#
# ['T364', 'Action 4520 4525', 'sick']
# This is the line  T365	Concept 4526 4532;4533 4538	Mitral valve
#
# ['T365', 'Concept 4526 4532;4533 4538', 'Mitral valve']
# This is the line  T366	Action 4539 4548	prolapse
#
# ['T366', 'Action 4539 4548', 'prolapse']
# This is the line  T367	Action 4558 4567	increases
#
# ['T367', 'Action 4558 4567', 'increases']
# This is the line  T368	Predicate 4572 4576	risk
#
# ['T368', 'Predicate 4572 4576', 'risk']
# This is the line  T369	Concept 4580 4592	endocarditis
#
# ['T369', 'Concept 4580 4592', 'endocarditis']
# This is the line  T370	Concept 4604 4609	heart
#
# ['T370', 'Concept 4604 4609', 'heart']
# This is the line  T371	Action 4610 4620	infection
#
# ['T371', 'Action 4610 4620', 'infection']
# This is the line  T372	Action 4628 4633	knows
#
# ['T372', 'Action 4628 4633', 'knows']
# This is the line  T373	Action 4638 4643	cause
#
# ['T373', 'Action 4638 4643', 'cause']
# This is the line  T374	Reference 4647 4651	this
#
# ['T374', 'Reference 4647 4651', 'this']
# This is the line  T375	Concept 4652 4661	syndrome
#
# ['T375', 'Concept 4652 4661', 'syndrome']
# This is the line  T376	Concept 4662 4674	Meningococci
#
# ['T376', 'Concept 4662 4674', 'Meningococci']
# This is the line  T377	Concept 4691 4699	problems
#
# ['T377', 'Concept 4691 4699', 'problems']
# This is the line  T378	Concept 4713 4720	serious
#
# ['T378', 'Concept 4713 4720', 'serious']
# This is the line  T379	Concept 4721 4732	bloodstream
#
# ['T379', 'Concept 4721 4732', 'bloodstream']
# This is the line  T380	Action 4733 4742	infection
#
# ['T380', 'Action 4733 4742', 'infection']
# This is the line  T381	Concept 4750 4757	sepsis
#
# ['T381', 'Concept 4750 4757', 'sepsis']
# This is the line  T382	Concept 4758 4762	Good
#
# ['T382', 'Concept 4758 4762', 'Good']
# This is the line  T383	Concept 4763 4770	hygiene
#
# ['T383', 'Concept 4763 4770', 'hygiene']
# This is the line  T384	Predicate 4771 4780	practices
#
# ['T384', 'Predicate 4771 4780', 'practices']
# This is the line  T385	Concept 4792 4798	proper
#
# ['T385', 'Concept 4792 4798', 'proper']
# This is the line  T386	Concept 4799 4803	hand
#
# ['T386', 'Concept 4799 4803', 'hand']
# This is the line  T387	Action 4804 4811	washing
#
# ['T387', 'Action 4804 4811', 'washing']
# This is the line  T388	Action 4817 4824	prevent
#
# ['T388', 'Action 4817 4824', 'prevent']
# This is the line  T389	Concept 4825 4836	infections
#
# ['T389', 'Concept 4825 4836', 'infections']
# This is the line  T390	Action 4837 4846	Treatment
#
# ['T390', 'Action 4837 4846', 'Treatment']
# This is the line  T391	Concept 4851 4855	hair
#
# ['T391', 'Concept 4851 4855', 'hair']
# This is the line  T392	Action 4856 4860	loss
#
# ['T392', 'Action 4856 4860', 'loss']
# This is the line  T393	Action 4861 4868	depends
#
# ['T393', 'Action 4861 4868', 'depends']
# This is the line  T394	Action 4876 4883	causes
#
# ['T394', 'Action 4876 4883', 'causes']
# This is the line  T395	Concept 4884 4893	Treatment
#
# ['T395', 'Concept 4884 4893', 'Treatment']
# This is the line  T396	Concept 4911 4918	surgery
#
# ['T396', 'Concept 4911 4918', 'surgery']
# This is the line  T397	Action 4922 4929	implant
#
# ['T397', 'Action 4922 4929', 'implant']
# This is the line  T398	Concept 4932 4938	shunt
#
# ['T398', 'Concept 4932 4938', 'shunt']
# This is the line  T399	Reference 4943 4947	that
#
# ['T399', 'Reference 4943 4947', 'that']
# This is the line  T400	Concept 4948 4954	reason
#
# ['T400', 'Concept 4948 4954', 'reason']
# This is the line  T401	Concept 4960 4966	health
#
# ['T401', 'Concept 4960 4966', 'health']
# This is the line  T402	Concept 4970 4978	homeless
#
# ['T402', 'Concept 4970 4978', 'homeless']
# This is the line  T403	Concept 5000 5006;5007 5013	United States
#
# ['T403', 'Concept 5000 5006;5007 5013', 'United States']
# This is the line  T404	Predicate 5017 5022	worse
#
# ['T404', 'Predicate 5017 5022', 'worse']
# This is the line  T405	Concept 5040 5047	general
#
# ['T405', 'Concept 5040 5047', 'general']
# This is the line  T406	Concept 5048 5059	population
#
# ['T406', 'Concept 5048 5059', 'population']
# This is the line  T407	Concept 5064 5071	surgery
#
# ['T407', 'Concept 5064 5071', 'surgery']
# This is the line  T408	Action 5072 5079	creates
#
# ['T408', 'Action 5072 5079', 'creates']
# This is the line  T409	Concept 5082 5085	new
#
# ['T409', 'Concept 5082 5085', 'new']
# This is the line  T410	Concept 5086 5093	pathway
#
# ['T410', 'Concept 5086 5093', 'pathway']
# This is the line  T411	Concept 5098 5103	blood
#
# ['T411', 'Concept 5098 5103', 'blood']
# This is the line  T412	Action 5107 5112	reach
#
# ['T412', 'Action 5107 5112', 'reach']
# This is the line  T413	Concept 5117 5123	heart
#
# ['T413', 'Concept 5117 5123', 'heart']
# This is the line  T414	Concept 5124 5130	Proper
#
# ['T414', 'Concept 5124 5130', 'Proper']
# This is the line  T415	Action 5131 5144	sterilization
#
# ['T415', 'Action 5131 5144', 'sterilization']
# This is the line  T416	Concept 5148 5157	equipment
#
# ['T416', 'Concept 5148 5157', 'equipment']
# This is the line  T417	Concept 5161 5171	important
#
# ['T417', 'Concept 5161 5171', 'important']
# This is the line  T418	Concept 5172 5185	Complications
#
# ['T418', 'Concept 5172 5185', 'Complications']
# This is the line  T419	Concept 5189 5193	lung
#
# ['T419', 'Concept 5189 5193', 'lung']
# This is the line  T420	Action 5194 5209	transplantation
#
# ['T420', 'Action 5194 5209', 'transplantation']
# This is the line  T421	Action 5218 5227	rejection
#
# ['T421', 'Action 5218 5227', 'rejection']
# This is the line  T422	Concept 5235 5247	transplanted
#
# ['T422', 'Concept 5235 5247', 'transplanted']
# This is the line  T423	Concept 5248 5252	lung
#
# ['T423', 'Concept 5248 5252', 'lung']
# This is the line  T424	Concept 5257 5268	infections
#
# ['T424', 'Concept 5257 5268', 'infections']
# This is the line  T425	Concept 5281 5287;5288 5296	rectal bleeding
#
# ['T425', 'Concept 5281 5287;5288 5296', 'rectal bleeding']
# This is the line  T426	Action 5308 5315	consult
#
# ['T426', 'Action 5308 5315', 'consult']
# This is the line  T427	Concept 5318 5325	doctor
#
# ['T427', 'Concept 5318 5325', 'doctor']
# This is the line  T428	Reference 5326 5329	You
#
# ['T428', 'Reference 5326 5329', 'You']
# This is the line  T429	Action 5330 5334	move
#
# ['T429', 'Action 5330 5334', 'move']
# This is the line  T430	Reference 5335 5337	it
#
# ['T430', 'Reference 5335 5337', 'it']
# This is the line  T431	Action 5347 5351	talk
#
# ['T431', 'Action 5347 5351', 'talk']
# This is the line  T432	Action 5355 5360	chew
#
# ['T432', 'Action 5355 5360', 'chew']
# This is the line  T433	Concept 5369 5376;5377 5383	 urinary system
#
# ['T433', 'Concept 5369 5376;5377 5383', ' urinary system']
# This is the line  T434	Action 5387 5398	functioning
#
# ['T434', 'Action 5387 5398', 'functioning']
# This is the line  T435	Concept 5399 5407	normally
#
# ['T435', 'Concept 5399 5407', 'normally']
# This is the line  T436	Concept 5414 5421	bladder
#
# ['T436', 'Concept 5414 5421', 'bladder']
# This is the line  T437	Action 5426 5430	hold
#
# ['T437', 'Action 5426 5430', 'hold']
# This is the line  T438	Concept 5437 5439;5440 5446	16 ounces
#
# ['T438', 'Concept 5437 5439;5440 5446', '16 ounces']
# This is the line  T439	Concept 5447 5453	177cc
#
# ['T439', 'Concept 5447 5453', '177cc']
# This is the line  T440	Concept 5457 5460;5461 5465	two cups
#
# ['T440', 'Concept 5457 5460;5461 5465', 'two cups']
# This is the line  T441	Concept 5470 5475	urine
#
# ['T441', 'Concept 5470 5475', 'urine']
# This is the line  T442	Concept 5476 5487	comfortably
#
# ['T442', 'Concept 5476 5487', 'comfortably']
# This is the line  T443	Predicate 5488 5495	betweem
#
# ['T443', 'Predicate 5488 5495', 'betweem']
# This is the line  T444	Concept 5496 5499	two
#
# ['T444', 'Concept 5496 5499', 'two']
# This is the line  T445	Concept 5503 5507	five
#
# ['T445', 'Concept 5503 5507', 'five']
# This is the line  T446	Concept 5508 5514	hours
#
# ['T446', 'Concept 5508 5514', 'hours']
# This is the line  T447	Action 5537 5542	avoid
#
# ['T447', 'Action 5537 5542', 'avoid']
# This is the line  T448	Concept 5553 5556	age
#
# ['T448', 'Concept 5553 5556', 'age']
# This is the line  T449	Concept 5562 5568	bodies
#
# ['T449', 'Concept 5562 5568', 'bodies']
# This is the line  T450	Concept 5573 5578	minds
#
# ['T450', 'Concept 5573 5578', 'minds']
# This is the line  T451	Action 5579 5586	change
#
# ['T451', 'Action 5579 5586', 'change']
# This is the line  T452	Concept 5592 5597	blood
#
# ['T452', 'Concept 5592 5597', 'blood']
# This is the line  T453	Action 5598 5606	problems
#
# ['T453', 'Action 5598 5606', 'problems']
# This is the line  T454	Action 5619 5627	clotting
#
# ['T454', 'Action 5619 5627', 'clotting']
# This is the line  T455	Action 5628 5636	problems
#
# ['T455', 'Action 5628 5636', 'problems']
# This is the line  T456	Concept 5638 5643;5644 5649	blood clots
#
# ['T456', 'Concept 5638 5643;5644 5649', 'blood clots']
# This is the line  T457	Concept 5654 5662	platelet
#
# ['T457', 'Concept 5654 5662', 'platelet']
# This is the line  T458	Concept 5663 5673	disorders
#
# ['T458', 'Concept 5663 5673', 'disorders']
# This is the line  T459	Concept 5674 5684	Scientists
#
# ['T459', 'Concept 5674 5684', 'Scientists']
# This is the line  T460	Action 5698 5702	know
#
# ['T460', 'Action 5698 5702', 'know']
# This is the line  T461	Reference 5703 5706	the
#
# ['T461', 'Reference 5703 5706', 'the']
# This is the line  T462	Concept 5707 5713	cause
#
# ['T462', 'Concept 5707 5713', 'cause']
# This is the line  T463	Concept 5714 5724;5725 5731	Peripheral nerves
#
# ['T463', 'Concept 5714 5724;5725 5731', 'Peripheral nerves']
# This is the line  T464	Action 5732 5739	conduct
#
# ['T464', 'Action 5732 5739', 'conduct']
# This is the line  T465	Concept 5740 5748	movement
#
# ['T465', 'Concept 5740 5748', 'movement']
# This is the line  T466	Concept 5753 5762	sensation
#
# ['T466', 'Concept 5753 5762', 'sensation']
# This is the line  T467	Predicate 5763 5770	signals
#
# ['T467', 'Predicate 5763 5770', 'signals']
# This is the line  T468	Predicate 5771 5778	between
#
# ['T468', 'Predicate 5771 5778', 'between']
# This is the line  T469	Concept 5783 5788	brain
#
# ['T469', 'Concept 5783 5788', 'brain']
# This is the line  T470	Concept 5790 5796;5797 5801	spinal cord
#
# ['T470', 'Concept 5790 5796;5797 5801', 'spinal cord']
# This is the line  T471	Predicate 5810 5814	rest
#
# ['T471', 'Predicate 5810 5814', 'rest']
# This is the line  T472	Concept 5822 5827	body
#
# ['T472', 'Concept 5822 5827', 'body']
# This is the line  T473	Concept 5828 5836	Vaccines
#
# ['T473', 'Concept 5828 5836', 'Vaccines']
# This is the line  T474	Predicate 5837 5844	against
#
# ['T474', 'Predicate 5837 5844', 'against']
# This is the line  T475	Concept 5845 5848	HPV
#
# ['T475', 'Concept 5845 5848', 'HPV']
# This is the line  T476	Action 5853 5857	help
#
# ['T476', 'Action 5853 5857', 'help']
# This is the line  T477	Action 5858 5865	prevent
#
# ['T477', 'Action 5858 5865', 'prevent']
# This is the line  T478	Action 5871 5881	infections
#
# ['T478', 'Action 5871 5881', 'infections']
# This is the line  T479	Reference 5887 5891	this
#
# ['T479', 'Reference 5887 5891', 'this']
# This is the line  T480	Concept 5892 5897	virus
#
# ['T480', 'Concept 5892 5897', 'virus']
# This is the line  T481	Concept 5909 5916	genital
#
# ['T481', 'Concept 5909 5916', 'genital']
# This is the line  T482	Concept 5917 5923	warts
#
# ['T482', 'Concept 5917 5923', 'warts']
# This is the line  T483	Reference 5924 5929	These
#
# ['T483', 'Reference 5924 5929', 'These']
# This is the line  T484	Concept 5930 5936	glands
#
# ['T484', 'Concept 5930 5936', 'glands']
# This is the line  T485	Action 5937 5944	produce
#
# ['T485', 'Action 5937 5944', 'produce']
# This is the line  T486	Concept 5945 5953	hormones
#
# ['T486', 'Concept 5945 5953', 'hormones']
# This is the line  T487	Concept 5963 5972	essential
#
# ['T487', 'Concept 5963 5972', 'essential']
# This is the line  T488	Concept 5977 5981	life
#
# ['T488', 'Concept 5977 5981', 'life']
# This is the line  T489	Concept 5993 5996;5997 6005	sex hormones
#
# ['T489', 'Concept 5993 5996;5997 6005', 'sex hormones']
# This is the line  T490	Concept 6010 6018	cortisol
#
# ['T490', 'Concept 6010 6018', 'cortisol']
# This is the line  T491	Action 6026 6031	helps
#
# ['T491', 'Action 6026 6031', 'helps']
# This is the line  T492	Action 6032 6039	respond
#
# ['T492', 'Action 6032 6039', 'respond']
# This is the line  T493	Concept 6043 6049	stress
#
# ['T493', 'Concept 6043 6049', 'stress']
# This is the line  T494	Predicate 6063 6068	other
#
# ['T494', 'Predicate 6063 6068', 'other']
# This is the line  T495	Concept 6069 6079	functions
#
# ['T495', 'Concept 6069 6079', 'functions']
# This is the line  T496	Concept 6080 6090	Hurricanes
#
# ['T496', 'Concept 6080 6090', 'Hurricanes']
# This is the line  T497	Action 6112 6119	damage
#
# ['T497', 'Action 6112 6119', 'damage']
# This is the line  T498	Predicate 6128 6132	type
#
# ['T498', 'Predicate 6128 6132', 'type']
# This is the line  T499	Concept 6136 6142;6143 6147	neural tube
#
# ['T499', 'Concept 6136 6142;6143 6147', 'neural tube']
# This is the line  T500	Concept 6148 6154	defect
#
# ['T500', 'Concept 6148 6154', 'defect']
# This is the line  T501	Concept 6158 6164;6165 6178	Chiari malformations
#
# ['T501', 'Concept 6158 6164;6165 6178', 'Chiari malformations']
# This is the line  T502	Concept 6193 6198	brain
#
# ['T502', 'Concept 6193 6198', 'brain']
# This is the line  T503	Concept 6199 6205	tissue
#
# ['T503', 'Concept 6199 6205', 'tissue']
# This is the line  T504	Action 6209 6215	extend
#
# ['T504', 'Action 6209 6215', 'extend']
# This is the line  T505	Concept 6225 6231;6232 6238	spinal canal
#
# ['T505', 'Concept 6225 6231;6232 6238', 'spinal canal']
# This is the line  T506	Concept 6243 6251	shoulder
#
# ['T506', 'Concept 6243 6251', 'shoulder']
# This is the line  T507	Concept 6252 6257	joint
#
# ['T507', 'Concept 6252 6257', 'joint']
# This is the line  T508	Action 6261 6269	composed
#
# ['T508', 'Action 6261 6269', 'composed']
# This is the line  T509	Predicate 6273 6278	three
#
# ['T509', 'Predicate 6273 6278', 'three']
# This is the line  T510	Concept 6279 6284	bones
#
# ['T510', 'Concept 6279 6284', 'bones']
# This is the line  T511	Concept 6290 6298	clavicle
#
# ['T511', 'Concept 6290 6298', 'clavicle']
# This is the line  T512	Concept 6304 6311	scapula
#
# ['T512', 'Concept 6304 6311', 'scapula']
# This is the line  T513	Concept 6320 6328	humerus
#
# ['T513', 'Concept 6320 6328', 'humerus']
# This is the line  T514	Concept 6329 6335	Speech
#
# ['T514', 'Concept 6329 6335', 'Speech']
# This is the line  T515	Concept 6340 6348	language
#
# ['T515', 'Concept 6340 6348', 'language']
# This is the line  T516	Action 6349 6360	development
#
# ['T516', 'Action 6349 6360', 'development']
# This is the line  T517	Concept 6364 6372	children
#
# ['T517', 'Concept 6364 6372', 'children']
# This is the line  T518	Action 6373 6380	varies
#
# ['T518', 'Action 6373 6380', 'varies']
# ...
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R96', type='entails', arg1='T121', arg2='T117')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R97', type='target', arg1='T120', arg2='T117')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R98', type='subject', arg1='T126', arg2='T123')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R99', type='target', arg1='T125', arg2='T123')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R100', type='subject', arg1='T126', arg2='T123')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R101', type='target', arg1='T127', arg2='T123')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R102', type='entails', arg1='T126', arg2='T125')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R103', type='entails', arg1='T126', arg2='T127')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R104', type='domain', arg1='T131', arg2='T132')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R105', type='subject', arg1='T130', arg2='T128')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R106', type='target', arg1='T130', arg2='T131')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R107', type='arg', arg1='T131', arg2='T133')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R108', type='in-context', arg1='T128', arg2='T129')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R109', type='arg', arg1='T135', arg2='T138')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R110', type='in-place', arg1='T138', arg2='T136')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R111', type='in-place', arg1='T138', arg2='T137')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R112', type='is-a', arg1='T134', arg2='T135')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R113', type='in-context', arg1='T142', arg2='T143')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R114', type='target', arg1='T141', arg2='T140')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R115', type='causes', arg1='T139', arg2='T141')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R116', type='causes', arg1='T141', arg2='T142')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R117', type='subject', arg1='T145', arg2='T144')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R118', type='target', arg1='T145', arg2='T146')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R119', type='subject', arg1='T148', arg2='T147')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R120', type='target', arg1='T148', arg2='T149')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R121', type='subject', arg1='T150', arg2='T148')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R122', type='in-context', arg1='T150', arg2='T151')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R123', type='in-context', arg1='T153', arg2='T152')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R124', type='in-context', arg1='T155', arg2='T154')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R125', type='arg', arg1='T155', arg2='T156')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R126', type='is-a', arg1='T153', arg2='T155')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R127', type='has-property', arg1='T158', arg2='T157')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R128', type='domain', arg1='T162', arg2='T163')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R129', type='arg', arg1='T161', arg2='T162')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R130', type='in-context', arg1='T160', arg2='T159')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R131', type='target', arg1='T158', arg2='T160')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R132', type='entails', arg1='T153', arg2='T158')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R133', type='in-time', arg1='T158', arg2='T161')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R134', type='arg', arg1='T165', arg2='T164')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R135', type='subject', arg1='T166', arg2='T165')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R136', type='target', arg1='T166', arg2='T167')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R137', type='in-context', arg1='T169', arg2='T168')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R138', type='arg', arg1='T167', arg2='T169')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R139', type='is-a', arg1='T170', arg2='T171')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R140', type='in-context', arg1='T166', arg2='T172')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R141', type='arg', arg1='T167', arg2='T170')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R142', type='arg', arg1='T167', arg2='T171')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R143', type='in-context', arg1='T178', arg2='T177')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R144', type='target', arg1='T175', arg2='T174')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R145', type='in-context', arg1='T175', arg2='T173')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R146', type='causes', arg1='T176', arg2='T175')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R147', type='causes', arg1='T178', arg2='T175')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R148', type='causes', arg1='T179', arg2='T175')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R149', type='causes', arg1='T180', arg2='T175')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R150', type='in-context', arg1='T182', arg2='T183')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R151', type='is-a', arg1='T181', arg2='T182')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R152', type='in-context', arg1='T187', arg2='T186')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R153', type='is-a', arg1='T183', arg2='T187')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R154', type='domain', arg1='T184', arg2='T187')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R155', type='arg', arg1='T184', arg2='T185')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='*36', type='same-as', args=['T183', 'T184'])>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R156', type='subject', arg1='T189', arg2='T188')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R157', type='target', arg1='T189', arg2='T190')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R158', type='target', arg1='T192', arg2='T190')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R159', type='in-context', arg1='T189', arg2='T192')>' has been ignored.
#   warnings.warn(
# C:\Erne\Baylor\Investigacion\Cerny\ranker\scripts\utils.py:694: UserWarning: In file 'data\testing\scenario1-main\scenario.txt' annotation '<Relation(id='R160', type='is-a', arg1='T190', arg2='T191')>' has been ignored.
#   warnings.warn(

# %%
train_20 = Collection(train_20.sentences[:800])

# %%
sentence = train_20.sentences[7]
sentence
# Out:
# Sentence(text='However, if you feel itching all over your body, have hives that keep coming back, or have itching with no apparent cause, you may need medical attention.', keyphrases=[Keyphrase(text='feel', label='Action', id=39, attr=[]), Keyphrase(text='itching', label='Action', id=40, attr=[]), Keyphrase(text='all', label='Predicate', id=41, attr=[]), Keyphrase(text='body,', label='Concept', id=42, attr=[]), Keyphrase(text='hives', label='Concept', id=43, attr=[]), Keyphrase(text='keep', label='Action', id=44, attr=[]), Keyphrase(text='coming back', label='Action', id=45, attr=[]), Keyphrase(text='itching', label='Action', id=46, attr=[]), Keyphrase(text='cause', label='Concept', id=47, attr=[]), Keyphrase(text='need', label='Action', id=48, attr=[]), Keyphrase(text='medical attention.', label='Concept', id=49, attr=[])], relations=[Relation(from='itching', to='cause', label='in-context'), Relation(from='itching', to='all', label='in-place'), Relation(from='all', to='body,', label='domain'), Relation(from='keep', to='coming back', label='target'), Relation(from='keep', to='hives', label='subject'), Relation(from='coming back', to='hives', label='target'), Relation(from='need', to='medical attention.', label='target'), Relation(from='need', to='itching', label='in-context'), Relation(from='need', to='keep', label='in-context'), Relation(from='need', to='feel', label='in-context'), Relation(from='feel', to='itching', label='target')])

# %%
text = sentence.text

# %%
bert = BERTComponent('bert-large-cased')
# Out:
# Tokenizer:  PreTrainedTokenizer(name_or_path='bert-large-cased', vocab_size=28996, model_max_len=512, is_fast=False, padding_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'})

# %%
from nltk.tokenize import TreebankWordTokenizer as twt
spans = list(twt().span_tokenize(text))

# %%
spans
# Out:
# [(0, 7),
#  (7, 8),
#  (9, 11),
#  (12, 15),
#  (16, 20),
#  (21, 28),
#  (29, 32),
#  (33, 37),
#  (38, 42),
#  (43, 47),
#  (47, 48),
#  (49, 53),
#  (54, 59),
#  (60, 64),
#  (65, 69),
#  (70, 76),
#  (77, 81),
#  (81, 82),
#  (83, 85),
#  (86, 90),
#  (91, 98),
#  (99, 103),
#  (104, 106),
#  (107, 115),
#  (116, 121),
#  (121, 122),
#  (123, 126),
#  (127, 130),
#  (131, 135),
#  (136, 143),
#  (144, 153),
#  (153, 154)]

# %%
sentence
# Out:
# Sentence(text='However, if you feel itching all over your body, have hives that keep coming back, or have itching with no apparent cause, you may need medical attention.', keyphrases=[Keyphrase(text='feel', label='Action', id=39, attr=[]), Keyphrase(text='itching', label='Action', id=40, attr=[]), Keyphrase(text='all', label='Predicate', id=41, attr=[]), Keyphrase(text='body,', label='Concept', id=42, attr=[]), Keyphrase(text='hives', label='Concept', id=43, attr=[]), Keyphrase(text='keep', label='Action', id=44, attr=[]), Keyphrase(text='coming back', label='Action', id=45, attr=[]), Keyphrase(text='itching', label='Action', id=46, attr=[]), Keyphrase(text='cause', label='Concept', id=47, attr=[]), Keyphrase(text='need', label='Action', id=48, attr=[]), Keyphrase(text='medical attention.', label='Concept', id=49, attr=[])], relations=[Relation(from='itching', to='cause', label='in-context'), Relation(from='itching', to='all', label='in-place'), Relation(from='all', to='body,', label='domain'), Relation(from='keep', to='coming back', label='target'), Relation(from='keep', to='hives', label='subject'), Relation(from='coming back', to='hives', label='target'), Relation(from='need', to='medical attention.', label='target'), Relation(from='need', to='itching', label='in-context'), Relation(from='need', to='keep', label='in-context'), Relation(from='need', to='feel', label='in-context'), Relation(from='feel', to='itching', label='target')])

# %%
text
# Out:
# 'However, if you feel itching all over your body, have hives that keep coming back, or have itching with no apparent cause, you may need medical attention.'

# %%
text = sentence.text
spans = list(twt().span_tokenize(text))

# %%
text_word_embeddings, text_embedding = bert.get_bert_embeddings(text, spans)

# %%
text_word_embeddings
# Out:
# [tensor([-0.4310, -1.1438,  0.0899,  ...,  1.2625, -0.7967,  0.0751]),
#  tensor([-0.0457, -0.3175,  0.0430,  ...,  1.0440, -0.7202,  0.5596]),
#  tensor([ 0.1354,  0.9362, -0.2143,  ...,  0.5116, -0.9073, -0.3039]),
#  tensor([ 0.4726, -0.2852,  0.0030,  ...,  0.4294, -0.8079,  0.2888]),
#  tensor([-0.5834,  0.2132,  0.2505,  ..., -0.0095,  0.5432, -0.2030]),
#  tensor([ 0.3509,  0.1296, -0.2321,  ...,  0.5885,  0.0217, -0.0660]),
#  tensor([-0.0645,  0.3081, -0.1070,  ...,  0.0178, -0.4771, -0.2134]),
#  tensor([ 0.1650,  0.2231, -0.2524,  ...,  0.3522, -0.2927, -0.5516]),
#  tensor([ 1.0647,  0.4675, -0.0213,  ...,  0.3438, -0.3550,  0.1908]),
#  tensor([ 0.6960,  0.5852, -0.2437,  ..., -0.2017,  0.2033, -0.2405]),
#  tensor([-0.5446, -1.0509, -0.3094,  ...,  0.4499,  0.8804,  0.1090]),
#  tensor([-0.0116,  0.2647,  0.3383,  ...,  0.9281,  0.5913, -0.2400]),
#  tensor([ 0.3599, -0.2769,  0.3066,  ...,  0.3681,  0.2989, -0.1741]),
#  tensor([ 0.4502,  0.0050,  0.0980,  ...,  1.1149, -0.2044, -0.3441]),
#  tensor([ 0.1447,  1.2873, -0.3389,  ..., -0.3561, -0.2542,  0.0331]),
#  tensor([ 0.3226,  1.3813, -0.5284,  ..., -0.5567,  0.7631, -0.7786]),
#  tensor([ 0.3530,  1.1079, -1.1395,  ..., -0.0267,  1.4860, -1.2319]),
#  tensor([-0.7520, -0.5853, -0.2552,  ...,  0.8855,  0.5376,  1.1144]),
#  tensor([ 0.0997, -0.2400, -0.3467,  ...,  0.9395, -0.4049, -1.2843]),
#  tensor([ 0.2064,  0.5107,  0.3950,  ...,  0.2966, -0.0416, -0.4206]),
#  tensor([ 0.5238,  0.0645, -0.4803,  ...,  0.2013, -0.2351, -0.3458]),
#  tensor([ 0.5488,  1.2929, -0.1279,  ..., -0.1100, -0.8781,  0.2003]),
#  tensor([ 0.9894,  0.2952,  0.5616,  ..., -0.9483, -0.7680,  0.0675]),
#  tensor([ 0.7417,  0.7335,  0.1380,  ..., -0.9614, -0.1098, -0.2683]),
#  tensor([-0.0128,  0.6591, -0.3453,  ...,  0.6078, -0.4106, -0.3315]),
#  tensor([ 0.1125, -0.3555, -0.0936,  ...,  1.3848, -0.3485,  0.6152]),
#  tensor([ 0.7323, -0.0650, -0.2051,  ...,  0.3764, -1.0903,  0.3437]),
#  tensor([ 0.3391,  0.3162,  0.1368,  ...,  1.4694, -1.3001, -0.1695]),
#  tensor([0.2037, 0.8751, 0.3057,  ..., 0.9746, 0.0472, 0.5821]),
#  tensor([ 0.4634, -0.5375, -0.1506,  ...,  0.3058,  0.0030,  0.0622]),
#  tensor([-0.2467, -0.5042,  0.0873,  ...,  0.9928, -0.1930,  0.4000]),
#  tensor([ 0.3323, -0.6973, -0.3679,  ...,  0.0469,  0.0463,  0.0502])]

# %%
test_embedding_prev = text_word_embeddings[5]

# %%
test_embedding_prev
# Out:
# tensor([ 0.3509,  0.1296, -0.2321,  ...,  0.5885,  0.0217, -0.0660])

# %%
text2 = 'However, if you feel itching all over your body, have hives that keep coming back, or have itching with no apparent cause, you may need medical attention.'
spans2 = list(twt().span_tokenize(text2))
text_word_embeddings2, text_embedding2 = bert.get_bert_embeddings(text2, spans2)
test_embedding_changed = text_word_embeddings2[5]

# %%
from torch import nn
criterion = nn.L1Loss()
loss = criterion(test_embedding_prev, test_embedding_changed)
print(loss)
# Out:
# tensor(0.0290)

# %%
from sklearn.metrics.pairwise import cosine_similarity
score = cosine_similarity([test_embedding_prev.numpy()], [test_embedding_changed.numpy()])[0][0]
print(score)
# Out:
# 0.9984857

# %%
sentence
# Out:
# Sentence(text='However, if you feel itching all over your body, have hives that keep coming back, or have itching with no apparent cause, you may need medical attention.', keyphrases=[Keyphrase(text='feel', label='Action', id=39, attr=[]), Keyphrase(text='itching', label='Action', id=40, attr=[]), Keyphrase(text='all', label='Predicate', id=41, attr=[]), Keyphrase(text='body,', label='Concept', id=42, attr=[]), Keyphrase(text='hives', label='Concept', id=43, attr=[]), Keyphrase(text='keep', label='Action', id=44, attr=[]), Keyphrase(text='coming back', label='Action', id=45, attr=[]), Keyphrase(text='itching', label='Action', id=46, attr=[]), Keyphrase(text='cause', label='Concept', id=47, attr=[]), Keyphrase(text='need', label='Action', id=48, attr=[]), Keyphrase(text='medical attention.', label='Concept', id=49, attr=[])], relations=[Relation(from='itching', to='cause', label='in-context'), Relation(from='itching', to='all', label='in-place'), Relation(from='all', to='body,', label='domain'), Relation(from='keep', to='coming back', label='target'), Relation(from='keep', to='hives', label='subject'), Relation(from='coming back', to='hives', label='target'), Relation(from='need', to='medical attention.', label='target'), Relation(from='need', to='itching', label='in-context'), Relation(from='need', to='keep', label='in-context'), Relation(from='need', to='feel', label='in-context'), Relation(from='feel', to='itching', label='target')])

# %%
from sklearn.metrics.pairwise import cosine_similarity

sentences = train_20.sentences[:800]

dicOriginalSim = {}
dicResSim = {}
dicNotEntSim = {}

for sentence in sentences:
    text = sentence.text
    spans = list(twt().span_tokenize())
    keyphrases = sentence.keyphrases
    for source in keyphrases:
        for target in keyphrases:
            if source.text == target.text:
                continue
            
            text_word_embeddings, text_embedding = bert.get_bert_embeddings(text, spans)
            #Map Entity to embedding:
            
            sourceEmbedding = None
            targetEmbedding = None
            for i in range(len(spans)):
                span = spans[i]
                word = text[span[0]:span[1]]
                if word == source.text:
                    sourceEmbedding = text_word_embeddings[i]
                elif word == target.text:
                    targetEmbedding = text_word_embeddings[i]
            
            score = cosine_similarity([sourceEmbedding.numpy()], [targetEmbedding.numpy()])[0][0]
            
            dicOriginalSim[(source.id, target.id)] = score
            dicOriginalSim[(target.id, source.id)] = score
            
            #Remove specifically the word entity that we are now: (Consider doing it in both directions and stay with the biggest)

# %%
sentence.keyphrases
# Out:
# [Keyphrase(text='feel', label='Action', id=39, attr=[]),
#  Keyphrase(text='itching', label='Action', id=40, attr=[]),
#  Keyphrase(text='all', label='Predicate', id=41, attr=[]),
#  Keyphrase(text='body,', label='Concept', id=42, attr=[]),
#  Keyphrase(text='hives', label='Concept', id=43, attr=[]),
#  Keyphrase(text='keep', label='Action', id=44, attr=[]),
#  Keyphrase(text='coming back', label='Action', id=45, attr=[]),
#  Keyphrase(text='itching', label='Action', id=46, attr=[]),
#  Keyphrase(text='cause', label='Concept', id=47, attr=[]),
#  Keyphrase(text='need', label='Action', id=48, attr=[]),
#  Keyphrase(text='medical attention.', label='Concept', id=49, attr=[])]
